# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanKrishna19/pavan/blob/main/Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Null Values means missing values
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ## **1) Show the number of confirmed ,deaths and recovered cases in each region.**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum(0)
# Out:
# <ipython-input-16-5b8cf32d8dec>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered'].sum(0)
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# 2)Remove all the records where Confirmed Cases is less than 10.**bold text**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data=data[~(data.Confirmed < 10)] #To remove the records satisfying a particular condition

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# 3)In which Region ,maximum number of Confirmed cases were  recorded?**bold text**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending =False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# **4) In which Region , minimum number of deaths cases were recorded?**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %% [markdown]
# 5)How many Confirmed , Deaths & Recovered cases were reported from India till 29 april 2020?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Region =='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region =='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# **6) Sort the entire data wrt no . of confirmed cases in ascending order.**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by =['Confirmed'], ascending =True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %% [markdown]
# **7) Sort the entire data wrt no of recovered cases in descending order**

# %%
data.sort_values(by=['Recovered'],ascending =False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 285  4/29/2020        Recovered                    US          0       0
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 284  4/29/2020        Recovered                Canada          0       0
# 78   4/29/2020              NaN               Ireland      20253    1190
# ...
